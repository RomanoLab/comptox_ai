# %%
import requests
import pandas as pd
import os, sys
import time
from tqdm import tqdm_notebook

# %%
# Load API key
API_KEY = "e72f9f9d5011325e78ac58c5736911857607"

# %%
# TODO: Modify to point to a file hosted in the ComptoxAI repository with relative path
# Note: These are MeSH identifiers. We use Entrez to map them as a SourceID to PubChem identifiers instead
mesh_ids_file = "~/data/ctdbase/ctd_chemical_identifiers.txt"

chemical_mapping = pd.read_csv(mesh_ids_file, header=None)

# %%
chemical_mapping.columns = ['mesh']

# %%
chemical_mapping['pubchem_cid'] = None
chemical_mapping['pubchem_sid'] = None
chemical_mapping['casrn'] = None
chemical_mapping['dtxsid'] = None

# %%
chemical_mapping
# Out:
#               mesh pubchem_cid pubchem_sid casrn dtxsid
# 0          C089250        None        None  None   None
# 1          C114385        None        None  None   None
# 2          C114386        None        None  None   None
# 3          C434150        None        None  None   None
# 4          C434149        None        None  None   None
# ...            ...         ...         ...   ...    ...
# 176066     C482761        None        None  None   None
# 176067  C000712888        None        None  None   None
# 176068     C558532        None        None  None   None
# 176069     C483463        None        None  None   None
# 176070     C558533        None        None  None   None
#
# [176071 rows x 5 columns]

# %%
chemical_mapping_test = chemical_mapping.head(n=27)

# %%
BASE_URL = 'https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi'

def get_pubchem_sid(mesh_id):
    payload = {
        'db': 'pcsubstance',
        'term': f"{mesh_id}[SourceID]",
        'retmode': 'json',
        'api_key': API_KEY
    }
    r = requests.post(url=BASE_URL, params=payload)
    try:
        return r.json()['esearchresult']['idlist']
    except:
        return []

for i, m in enumerate(tqdm_notebook(chemical_mapping['mesh'])):
    sid_col_idx = chemical_mapping.columns.get_loc('pubchem_sid')
    sid = get_pubchem_cid(m)
    assert(len(cid) < 2)

    if len(cid) == 1:
        cid = cid[0]
        chemical_mapping_test.iloc[i, sid_col_idx] = cid

    if i%10 == 0:
        time.sleep(0.1)
# Out:
# /var/folders/mb/jkjn3zh97jz9dbxlswr4mj8c0000gn/T/ipykernel_88309/134363505.py:16: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i, m in enumerate(tqdm_notebook(chemical_mapping['mesh'])):
#   0%|          | 0/176071 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[92], line 18
#      16 for i, m in enumerate(tqdm_notebook(chemical_mapping['mesh'])):
#      17     sid_col_idx = chemical_mapping.columns.get_loc('pubchem_sid')
# ---> 18     sid = get_pubchem_cid(m)
#      19     assert(len(cid) < 2)
#      21     if len(cid) == 1:
#
# Cell In[91], line 12, in get_pubchem_cid(mesh_id)
#       5 def get_pubchem_cid(mesh_id):
#       6     payload = {
#       7         'db': 'pcsubstance',
#       8         'term': f"{mesh_id}[SourceID]",
# ...

# %%
chemical_mapping_test
# Out:
#           mesh pubchem_cid pubchem_sid casrn dtxsid
# 0      C089250        None        None  None   None
# 1      C114385        None        None  None   None
# 2      C114386        None        None  None   None
# 3      C434150        None        None  None   None
# 4      C434149        None        None  None   None
# 5   C000620092        None        None  None   None
# 6      C533344        None        None  None   None
# 7      C533345        None        None  None   None
# 8      C046983   134223433   134223433  None   None
# 9      C585814        None        None  None   None
# 10     C533898        None        None  None   None
# 11     C493119        None        None  None   None
# 12     C014305        None        None  None   None
# 13     C473129        None        None  None   None
# 14     C534883   252090125   252090125  None   None
# 15     C093446        None        None  None   None
# 16     C112297    85177289    85177289  None   None
# ...
